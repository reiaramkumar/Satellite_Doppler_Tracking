# %%
from comparision_plots import *
# Out:
# Setup done. Run your estimations, then call store() after each one.

# %%
# %run batch_runs.py
# Out:
# === Running noise_0p1 ===
# Stored 'noise_0p1' — 8 params, 86 obs, status=converged
#   Condition number: 8.20e+28
# Saved: noise_0p1
#
# === Running noise_1p0 ===
# Stored 'noise_1p0' — 8 params, 86 obs, status=converged
#   Condition number: 1.19e+29
# Saved: noise_1p0
#
# === Running noise_10 ===
# Stored 'noise_10' — 8 params, 86 obs, status=converged
#   Condition number: 1.04e+29
# Saved: noise_10
#
# === Running three_day_one_day_arcs ===
# Stored 'three_day_one_day_arcs' — 20 params, 240 obs, status=converged
#   Condition number: 4.73e+28
# Saved: three_day_one_day_arcs
#
# === Running manual_1km_1ms ===
# FAILED: manual_1km_1ms
# Error computing partials for observation of type OneWayDoppler with link ends transmitter: (Earth, DopTrackStation); receiver: (spacecraft) at epoch 638916906.523808.
# Original error: Error in variational equation solution interpolation.
# ...

# %%
print_summary()
# Out:
# | Config | σ_pos [m] | σ_vel [m/s] | σ_Cd | σ_μ | κ(P) | N_obs | Status |
# |--------|-----------|-------------|------|-----|------|-------|--------|
# | noise_0p1 | 295.778 | 0.256719 | 2.51979 | 5.91e+09 | 8.2e+28 | 86 | converged |
# | noise_1p0 | 2972.764 | 2.582127 | 25.37501 | 5.91e+10 | 1.2e+29 | 86 | converged |
# | noise_10 | 23639.298 | 19.717683 | 162.41681 | 6.07e+11 | 1.0e+29 | 86 | converged |
# | three_day_one_day_arcs | 2590.227 | 2.306888 | 4680.37530 | 7.90e+03 | 4.7e+28 | 240 | converged |
# | nearby_stations | 1281.401 | 1.112661 | 10.84810 | 3.01e+10 | 6.2e+28 | 258 | converged |
# | far | 71.645 | 0.122198 | 0.14396 | 6.49e+09 | 1.8e+27 | 223 | converged |
# | far_manual_1km_1ms | 71.647 | 0.122216 | 0.14396 | 6.49e+09 | 1.8e+27 | 223 | converged |
# | c20_c22_single_station | 8037.503 | 7.900586 | 171.09210 | 1.93e+11 | 2.5e+37 | 86 | converged |
# | c20_c22_far_stations | 86.048 | 0.126625 | 0.19350 | 7.00e+09 | 6.2e+34 | 223 | converged |
# ...

# %%
plot_formal()

# %%
plot_ratio()

# %%
plot_convergence()

# %%
plot_condition()

# %%
plot_dashboard()

# %%
export_all_png()
# Out:
#   Saved: figures\formal_errors.png
#   Saved: figures\ratio.png
#   Saved: figures\convergence.png
#   Saved: figures\condition.png
#   Saved: figures\dashboard.png
#
# All plots exported to 'figures/'.
